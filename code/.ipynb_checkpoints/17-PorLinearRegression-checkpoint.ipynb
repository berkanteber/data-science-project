# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as mpatches

import numpy as np
import pandas as pd

from sklearn import linear_model
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("../data/student/student-por.csv", delimiter=";")

# %%
lm = smf.ols(formula='G3 ~ G1 + G2', data=df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G3   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     906.1
# Date:                Sat, 29 Apr 2017   Prob (F-statistic):          1.01e-147
# Time:                        10:15:45   Log-Likelihood:                -820.11
# No. Observations:                 395   AIC:                             1646.
# Df Residuals:                     392   BIC:                             1658.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -1.8300      0.335     -5.458      0.000        -2.489    -1.171
# ...

# %%
X = np.array(df[['G1', 'G2']])
y = np.array(df['G3'])

regr = linear_model.LinearRegression()
regr.fit(X, y)

# Explained variance score
print('R^2: %.3f' % regr.score(X, y))
# Out:
# R^2: 0.822

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['G1'], df['G2'], df['G3'], c = 'blue')
ax.scatter(df['G1'], df['G2'], regr.predict(X), c = 'yellow')

blue_patch = mpatches.Patch(color='blue', label='Real Data')
yellow_patch = mpatches.Patch(color='yellow', label='Predicted Data')
plt.legend(handles=[blue_patch, yellow_patch])
plt.show()
